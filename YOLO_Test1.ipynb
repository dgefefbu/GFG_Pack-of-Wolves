# %%
from google.colab import drive
drive.mount('/content.gdrive')
# Out:
# Mounted at /content.gdrive

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15514, done.
# remote: Total 15514 (delta 0), reused 0 (delta 0), pack-reused 15514
# Receiving objects: 100% (15514/15514), 14.17 MiB | 18.23 MiB/s, done.
# Resolving deltas: 100% (10412/10412), done.

# %%
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# sed: can't read Makefile: No such file or directory
# sed: can't read Makefile: No such file or directory
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2023-04-08 18:29:08--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  61.9MB/s    in 4.1s
#
# 2023-04-08 18:29:12 (57.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libvorbis-dev is already the newest version (1.3.6-2ubuntu1).
# libvorbis-dev set to manually installed.
# libdc1394-22 is already the newest version (2.2.5-2.1).
# libdc1394-22 set to manually installed.
# libdc1394-22-dev is already the newest version (2.2.5-2.1).
# libdc1394-22-dev set to manually installed.
# libtbb-dev is already the newest version (2020.1-2).
# libtbb-dev set to manually installed.
# unzip is already the newest version (6.0-25ubuntu1.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libswscale-dev set to manually installed.
# qtbase5-dev is already the newest version (5.12.8+dfsg-0ubuntu2.1).
# qtbase5-dev set to manually installed.
# libopencv-dev is already the newest version (4.2.0+dfsg-5+focal2).
# The following additional packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-atk-1.0 gir1.2-atspi-2.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gst-plugins-base-1.0 gir1.2-gstreamer-1.0
#   gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 gstreamer1.0-gl
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk-bridge2.0-dev libatk1.0-dev libatspi2.0-dev libblkid-dev
#   libcairo-script-interpreter2 libcairo2-dev libcroco3 libdatrie-dev
#   libdbus-1-dev libdebhelper-perl libegl1-mesa-dev libepoxy-dev libfaac0
#   libffi-dev libffms2-4 libfile-stripnondeterminism-perl libfribidi-dev
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-dev libgl1-mesa-dev libgles-dev
#   libgles1 libgles2-mesa-dev libglib2.0-dev libglib2.0-dev-bin libglvnd-dev
#   libgpac4 libgraphene-1.0-0 libgraphite2-dev libgstreamer-gl1.0-0
#   libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0 liblzo2-2
#   libmail-sendmail-perl libmount-dev libopencore-amrnb0 libopencore-amrwb0
#   libopengl-dev liborc-0.4-dev liborc-0.4-dev-bin libpango1.0-dev
#   libpangoxft-1.0-0 libpixman-1-dev libpython2-stdlib libselinux1-dev
#   libsepol1-dev libsub-override-perl libsys-hostname-long-perl libthai-dev
#   libtool libv4l-0 libv4l2rds0 libv4lconvert0 libwayland-bin libwayland-dev
#   libx11-xcb-dev libxcb-render0-dev libxcb-shm0-dev libxcomposite-dev
#   libxcursor-dev libxdamage-dev libxfixes-dev libxi-dev libxine2-bin
#   libxinerama-dev libxkbcommon-dev libxrandr-dev libxtst-dev libxtst6
#   pango1.0-tools po-debconf python-pkg-resources python2 python2-minimal
#   wayland-protocols x11proto-input-dev x11proto-randr-dev x11proto-record-dev
#   x11proto-xinerama-dev
# Suggested packages:
#   dh-make gettext-doc libasprintf-dev libgettextpo-dev libcairo2-doc
#   libdatrie-doc libgirepository1.0-dev libglib2.0-doc libxml2-utils
#   libgraphite2-utils gstreamer1.0-doc libgtk-3-doc liborc-0.4-doc imagemagick
#   libpango1.0-doc libthai-doc libtool-doc gcj-jdk libwayland-doc
#   libmail-box-perl python-dev python-pytest python-numpy-dbg python-numpy-doc
#   python-setuptools python2-doc python-tk python3-pytest python3-numpy-dbg
# The following NEW packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-atk-1.0 gir1.2-atspi-2.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gst-plugins-base-1.0 gir1.2-gstreamer-1.0
#   gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 gstreamer1.0-gl
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk-bridge2.0-dev libatk1.0-dev libatspi2.0-dev libblkid-dev
#   libcairo-script-interpreter2 libcairo2-dev libcroco3 libdatrie-dev
#   libdbus-1-dev libdebhelper-perl libegl1-mesa-dev libepoxy-dev libfaac-dev
#   libfaac0 libffi-dev libffms2-4 libfile-stripnondeterminism-perl
#   libfribidi-dev libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-dev libgl1-mesa-dev
#   libgles-dev libgles1 libgles2-mesa-dev libglib2.0-dev libglib2.0-dev-bin
#   libglvnd-dev libgpac4 libgraphene-1.0-0 libgraphite2-dev
#   libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-dev libgstreamer1.0-dev
#   libgtk-3-dev libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0 liblzo2-2
#   libmail-sendmail-perl libmount-dev libmp3lame-dev libopencore-amrnb-dev
#   libopencore-amrnb0 libopencore-amrwb-dev libopencore-amrwb0 libopengl-dev
#   liborc-0.4-dev liborc-0.4-dev-bin libpango1.0-dev libpangoxft-1.0-0
#   libpixman-1-dev libpython2-stdlib libselinux1-dev libsepol1-dev
#   libsub-override-perl libsys-hostname-long-perl libthai-dev libtheora-dev
#   libtiff5-dev libtool libv4l-0 libv4l-dev libv4l2rds0 libv4lconvert0
#   libwayland-bin libwayland-dev libx11-xcb-dev libxcb-render0-dev
#   libxcb-shm0-dev libxcomposite-dev libxcursor-dev libxdamage-dev
#   libxfixes-dev libxi-dev libxine2-bin libxine2-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxtst-dev libxtst6 libxvidcore-dev
#   pango1.0-tools po-debconf python-numpy python-pkg-resources python2
#   python2-minimal python3-numpy v4l-utils wayland-protocols x11proto-input-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-xinerama-dev x264
# 0 upgraded, 116 newly installed, 0 to remove and 24 not upgraded.
# Need to get 21.8 MB of archives.
# After this operation, 121 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext-base amd64 0.19.8.1-10build1 [50.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 autopoint all 0.19.8.1-10build1 [412 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libtool all 2.4.6-14 [161 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-autoreconf all 19 [16.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libdebhelper-perl all 12.10ubuntu1 [62.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-zip-perl all 1.67-2 [90.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-override-perl all 0.09-2 [9,532 B]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libfile-stripnondeterminism-perl all 1.7.0-1 [15.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-strip-nondeterminism all 1.7.0-1 [5,228 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 dwz amd64 0.13-5 [151 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libcroco3 amd64 0.6.13-1 [82.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext amd64 0.19.8.1-10build1 [895 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 intltool-debian all 0.35.0+20060710.5 [24.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 po-debconf all 1.0.21 [233 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 debhelper all 12.10ubuntu1 [877 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-atk-1.0 amd64 2.35.1-1ubuntu2 [18.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-freedesktop amd64 1.64.1-1~ubuntu20.04.1 [19.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-atspi-2.0 amd64 2.36.0-2 [15.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.40.0+dfsg-3ubuntu0.4 [8,272 B]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.16.3-0ubuntu1.1 [72.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.16.3-0ubuntu1.1 [163 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gst-plugins-base-1.0 amd64 1.16.3-0ubuntu1.1 [85.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoxft-1.0-0 amd64 1.44.7-2ubuntu4 [18.0 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-pango-1.0 amd64 1.44.7-2ubuntu4 [26.6 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.20-0ubuntu1.1 [196 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-harfbuzz-0.0 amd64 2.6.4-1ubuntu4.2 [26.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphene-1.0-0 amd64 1.10.0-1build2 [42.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-gl amd64 1.16.3-0ubuntu1.1 [109 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.4 [109 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.3 [167 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.3 [176 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.4 [1,506 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbus-1-dev amd64 1.12.16-2ubuntu2.3 [167 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes-dev amd64 1:5.0.3-2 [11.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-input-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 libxi-dev amd64 2:1.7.10-0ubuntu1 [187 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-record-dev all 2019.2-1ubuntu1 [2,624 B]
# Get:46 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst-dev amd64 2:1.2.3-1 [15.2 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 libatspi2.0-dev amd64 2.36.0-2 [66.7 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libatk-bridge2.0-dev amd64 2.34.2-0ubuntu2~20.04.1 [3,140 B]
# Get:49 http://archive.ubuntu.com/ubuntu focal/main amd64 libatk1.0-dev amd64 2.35.1-1ubuntu2 [95.2 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo-script-interpreter2 amd64 1.16.0-4ubuntu1 [54.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpixman-1-dev amd64 0.38.4-0ubuntu2.1 [243 kB]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0-dev amd64 1.14-2 [18.4 kB]
# Get:54 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0-dev amd64 1.14-2 [6,716 B]
# Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2-dev amd64 1.16.0-4ubuntu1 [627 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/main amd64 libdatrie-dev amd64 0.2.12-3 [17.6 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles1 amd64 1.3.2-1~ubuntu0.20.04.2 [10.3 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles-dev amd64 1.3.2-1~ubuntu0.20.04.2 [47.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl-dev amd64 1.3.2-1~ubuntu0.20.04.2 [3,584 B]
# Get:60 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd-dev amd64 1.3.2-1~ubuntu0.20.04.2 [11.6 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [7,760 B]
# Get:62 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,420 B]
# Get:63 http://archive.ubuntu.com/ubuntu focal/main amd64 libepoxy-dev amd64 1.5.4-1 [126 kB]
# Get:64 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 libfaac0 amd64 1.30-1 [44.4 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 libfaac-dev amd64 1.30-1 [47.1 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/universe amd64 libffms2-4 amd64 2.23-4build1 [60.0 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfribidi-dev amd64 1.0.8-2ubuntu0.1 [62.3 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.40.0+dfsg-3ubuntu0.4 [14.1 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-dev amd64 2.40.0+dfsg-3ubuntu0.4 [43.6 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles2-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,424 B]
# Get:71 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgpac4 amd64 0.5.2-426-gc5ad4e4+dfsg5-5 [1,535 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphite2-dev amd64 1.3.13-11build1 [14.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer1.0-dev amd64 1.16.3-0ubuntu1.1 [484 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/main amd64 liborc-0.4-dev-bin amd64 1:0.4.31-1 [185 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/main amd64 liborc-0.4-dev amd64 1:0.4.31-1 [183 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-xcb-dev amd64 2:1.6.9-2ubuntu1.2 [9,800 B]
# Get:77 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-base1.0-dev amd64 1.16.3-0ubuntu1.1 [383 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz-icu0 amd64 2.6.4-1ubuntu4.2 [5,580 B]
# Get:79 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz-gobject0 amd64 2.6.4-1ubuntu4.2 [20.4 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libharfbuzz-dev amd64 2.6.4-1ubuntu4.2 [526 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 libthai-dev amd64 0.1.28-3 [24.5 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 pango1.0-tools amd64 1.44.7-2ubuntu4 [26.2 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/main amd64 libpango1.0-dev amd64 1.44.7-2ubuntu4 [132 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-bin amd64 1.18.0-1ubuntu0.1 [20.2 kB]
# Get:85 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-dev amd64 1.18.0-1ubuntu0.1 [64.6 kB]
# Get:86 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcomposite-dev amd64 1:0.4.5-1 [9,152 B]
# Get:87 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcursor-dev amd64 1:1.2.0-2 [26.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdamage-dev amd64 1:1.1.5-2 [5,228 B]
# Get:89 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xinerama-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:90 http://archive.ubuntu.com/ubuntu focal/main amd64 libxinerama-dev amd64 2:1.1.4-2 [7,896 B]
# Get:91 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbcommon-dev amd64 0.10.0-1 [45.4 kB]
# Get:92 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-randr-dev all 2019.2-1ubuntu1 [2,620 B]
# Get:93 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrandr-dev amd64 2:1.5.2-0ubuntu1 [25.0 kB]
# Get:94 http://archive.ubuntu.com/ubuntu focal/main amd64 wayland-protocols all 1.20-1 [60.3 kB]
# Get:95 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgtk-3-dev amd64 3.24.20-0ubuntu1.1 [1,067 kB]
# Get:96 http://archive.ubuntu.com/ubuntu focal/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:97 http://archive.ubuntu.com/ubuntu focal/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:98 http://archive.ubuntu.com/ubuntu focal/main amd64 libmp3lame-dev amd64 3.100-3 [153 kB]
# Get:99 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:100 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb-dev amd64 0.1.5-1 [106 kB]
# Get:101 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:102 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb-dev amd64 0.1.5-1 [50.6 kB]
# Get:103 http://archive.ubuntu.com/ubuntu focal/main amd64 libtheora-dev amd64 1.1.1+dfsg.1-15ubuntu2 [178 kB]
# Get:104 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtiff5-dev amd64 4.1.0+git191117-2ubuntu0.20.04.8 [2,260 B]
# Get:105 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4lconvert0 amd64 1.18.0-2build1 [76.5 kB]
# Get:106 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-0 amd64 1.18.0-2build1 [41.9 kB]
# Get:107 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l2rds0 amd64 1.18.0-2build1 [15.8 kB]
# Get:108 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-dev amd64 1.18.0-2build1 [108 kB]
# Get:109 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxine2-bin amd64 1.2.9-1build5 [1,441 kB]
# Get:110 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxine2-dev amd64 1.2.9-1build5 [73.3 kB]
# Get:111 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxvidcore-dev amd64 2:1.3.7-1 [344 kB]
# Get:112 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pkg-resources all 44.0.0-2ubuntu0.1 [130 kB]
# Get:113 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-numpy amd64 1:1.16.5-2ubuntu7 [2,144 kB]
# Get:114 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-numpy amd64 1:1.17.4-5ubuntu3.1 [2,724 kB]
# Get:115 http://archive.ubuntu.com/ubuntu focal/universe amd64 v4l-utils amd64 1.18.0-2build1 [586 kB]
# Get:116 http://archive.ubuntu.com/ubuntu focal/universe amd64 x264 amd64 2:0.155.2917+git0a84d98-2 [76.3 kB]
# Fetched 21.8 MB in 4s (4,999 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package python2-minimal.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 122378 files and directories currently installed.)
# Preparing to unpack .../000-python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../001-gettext-base_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-10build1) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../002-autopoint_0.19.8.1-10build1_all.deb ...
# Unpacking autopoint (0.19.8.1-10build1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../003-libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../004-dh-autoreconf_19_all.deb ...
# Unpacking dh-autoreconf (19) ...
# Selecting previously unselected package libdebhelper-perl.
# Preparing to unpack .../005-libdebhelper-perl_12.10ubuntu1_all.deb ...
# Unpacking libdebhelper-perl (12.10ubuntu1) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../006-libarchive-zip-perl_1.67-2_all.deb ...
# Unpacking libarchive-zip-perl (1.67-2) ...
# Selecting previously unselected package libsub-override-perl.
# Preparing to unpack .../007-libsub-override-perl_0.09-2_all.deb ...
# Unpacking libsub-override-perl (0.09-2) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../008-libfile-stripnondeterminism-perl_1.7.0-1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (1.7.0-1) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../009-dh-strip-nondeterminism_1.7.0-1_all.deb ...
# Unpacking dh-strip-nondeterminism (1.7.0-1) ...
# Selecting previously unselected package dwz.
# Preparing to unpack .../010-dwz_0.13-5_amd64.deb ...
# Unpacking dwz (0.13-5) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../011-libcroco3_0.6.13-1_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.13-1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../012-gettext_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext (0.19.8.1-10build1) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../013-intltool-debian_0.35.0+20060710.5_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.5) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../014-po-debconf_1.0.21_all.deb ...
# Unpacking po-debconf (1.0.21) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../015-debhelper_12.10ubuntu1_all.deb ...
# Unpacking debhelper (12.10ubuntu1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../016-gir1.2-atk-1.0_2.35.1-1ubuntu2_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../017-gir1.2-freedesktop_1.64.1-1~ubuntu20.04.1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Selecting previously unselected package gir1.2-atspi-2.0:amd64.
# Preparing to unpack .../018-gir1.2-atspi-2.0_2.36.0-2_amd64.deb ...
# Unpacking gir1.2-atspi-2.0:amd64 (2.36.0-2) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../019-gir1.2-gdkpixbuf-2.0_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# Preparing to unpack .../020-gir1.2-gstreamer-1.0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../021-libgstreamer-gl1.0-0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package gir1.2-gst-plugins-base-1.0:amd64.
# Preparing to unpack .../022-gir1.2-gst-plugins-base-1.0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gst-plugins-base-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../023-libpangoxft-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../024-gir1.2-pango-1.0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../025-gir1.2-gtk-3.0_3.24.20-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.20-0ubuntu1.1) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../026-gir1.2-harfbuzz-0.0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../027-libgraphene-1.0-0_1.10.0-1build2_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.10.0-1build2) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../028-gstreamer1.0-gl_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../029-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../030-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../031-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../032-libblkid-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../033-libmount-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../034-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../035-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../036-libglib2.0-dev_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../037-libdbus-1-dev_1.12.16-2ubuntu2.3_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../038-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../039-libxfixes-dev_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../040-x11proto-input-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-input-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../041-libxi-dev_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Selecting previously unselected package x11proto-record-dev.
# Preparing to unpack .../042-x11proto-record-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-record-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxtst-dev:amd64.
# Preparing to unpack .../043-libxtst-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libatspi2.0-dev:amd64.
# Preparing to unpack .../044-libatspi2.0-dev_2.36.0-2_amd64.deb ...
# Unpacking libatspi2.0-dev:amd64 (2.36.0-2) ...
# Selecting previously unselected package libatk-bridge2.0-dev:amd64.
# Preparing to unpack .../045-libatk-bridge2.0-dev_2.34.2-0ubuntu2~20.04.1_amd64.deb ...
# Unpacking libatk-bridge2.0-dev:amd64 (2.34.2-0ubuntu2~20.04.1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../046-libatk1.0-dev_2.35.1-1ubuntu2_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.35.1-1ubuntu2) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../047-liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../048-libcairo-script-interpreter2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../049-libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../050-libxcb-render0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../051-libxcb-shm0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../052-libcairo2-dev_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libdatrie-dev:amd64.
# Preparing to unpack .../053-libdatrie-dev_0.2.12-3_amd64.deb ...
# Unpacking libdatrie-dev:amd64 (0.2.12-3) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../054-libgles1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../055-libgles-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../056-libopengl-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../057-libglvnd-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../058-libegl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../059-libgl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libepoxy-dev:amd64.
# Preparing to unpack .../060-libepoxy-dev_1.5.4-1_amd64.deb ...
# Unpacking libepoxy-dev:amd64 (1.5.4-1) ...
# Selecting previously unselected package libfaac0:amd64.
# Preparing to unpack .../061-libfaac0_1.30-1_amd64.deb ...
# Unpacking libfaac0:amd64 (1.30-1) ...
# Selecting previously unselected package libfaac-dev:amd64.
# Preparing to unpack .../062-libfaac-dev_1.30-1_amd64.deb ...
# Unpacking libfaac-dev:amd64 (1.30-1) ...
# Selecting previously unselected package libffms2-4:amd64.
# Preparing to unpack .../063-libffms2-4_2.23-4build1_amd64.deb ...
# Unpacking libffms2-4:amd64 (2.23-4build1) ...
# Selecting previously unselected package libfribidi-dev:amd64.
# Preparing to unpack .../064-libfribidi-dev_1.0.8-2ubuntu0.1_amd64.deb ...
# Unpacking libfribidi-dev:amd64 (1.0.8-2ubuntu0.1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../065-libgdk-pixbuf2.0-bin_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev:amd64.
# Preparing to unpack .../066-libgdk-pixbuf2.0-dev_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package libgles2-mesa-dev:amd64.
# Preparing to unpack .../067-libgles2-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libgpac4:amd64.
# Preparing to unpack .../068-libgpac4_0.5.2-426-gc5ad4e4+dfsg5-5_amd64.deb ...
# Unpacking libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-5) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../069-libgraphite2-dev_1.3.13-11build1_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.13-11build1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../070-libgstreamer1.0-dev_1.16.3-0ubuntu1.1_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package liborc-0.4-dev-bin.
# Preparing to unpack .../071-liborc-0.4-dev-bin_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-dev-bin (1:0.4.31-1) ...
# Selecting previously unselected package liborc-0.4-dev:amd64.
# Preparing to unpack .../072-liborc-0.4-dev_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-dev:amd64 (1:0.4.31-1) ...
# Selecting previously unselected package libx11-xcb-dev:amd64.
# Preparing to unpack .../073-libx11-xcb-dev_2%3a1.6.9-2ubuntu1.2_amd64.deb ...
# Unpacking libx11-xcb-dev:amd64 (2:1.6.9-2ubuntu1.2) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-dev:amd64.
# Preparing to unpack .../074-libgstreamer-plugins-base1.0-dev_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../075-libharfbuzz-icu0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../076-libharfbuzz-gobject0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../077-libharfbuzz-dev_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libthai-dev:amd64.
# Preparing to unpack .../078-libthai-dev_0.1.28-3_amd64.deb ...
# Unpacking libthai-dev:amd64 (0.1.28-3) ...
# Selecting previously unselected package pango1.0-tools.
# Preparing to unpack .../079-pango1.0-tools_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking pango1.0-tools (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpango1.0-dev:amd64.
# Preparing to unpack .../080-libpango1.0-dev_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpango1.0-dev:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../081-libwayland-bin_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../082-libwayland-dev_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../083-libxcomposite-dev_1%3a0.4.5-1_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../084-libxcursor-dev_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2) ...
# Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../085-libxdamage-dev_1%3a1.1.5-2_amd64.deb ...
# Unpacking libxdamage-dev:amd64 (1:1.1.5-2) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../086-x11proto-xinerama-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../087-libxinerama-dev_2%3a1.1.4-2_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../088-libxkbcommon-dev_0.10.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.10.0-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../089-x11proto-randr-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-randr-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../090-libxrandr-dev_2%3a1.5.2-0ubuntu1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Selecting previously unselected package wayland-protocols.
# Preparing to unpack .../091-wayland-protocols_1.20-1_all.deb ...
# Unpacking wayland-protocols (1.20-1) ...
# Selecting previously unselected package libgtk-3-dev:amd64.
# Preparing to unpack .../092-libgtk-3-dev_3.24.20-0ubuntu1.1_amd64.deb ...
# Unpacking libgtk-3-dev:amd64 (3.24.20-0ubuntu1.1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../093-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../094-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmp3lame-dev:amd64.
# Preparing to unpack .../095-libmp3lame-dev_3.100-3_amd64.deb ...
# Unpacking libmp3lame-dev:amd64 (3.100-3) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../096-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrnb-dev:amd64.
# Preparing to unpack .../097-libopencore-amrnb-dev_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb-dev:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../098-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb-dev:amd64.
# Preparing to unpack .../099-libopencore-amrwb-dev_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb-dev:amd64 (0.1.5-1) ...
# Selecting previously unselected package libtheora-dev:amd64.
# Preparing to unpack .../100-libtheora-dev_1.1.1+dfsg.1-15ubuntu2_amd64.deb ...
# Unpacking libtheora-dev:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# Selecting previously unselected package libtiff5-dev.
# Preparing to unpack .../101-libtiff5-dev_4.1.0+git191117-2ubuntu0.20.04.8_amd64.deb ...
# Unpacking libtiff5-dev (4.1.0+git191117-2ubuntu0.20.04.8) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../102-libv4lconvert0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../103-libv4l-0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l2rds0:amd64.
# Preparing to unpack .../104-libv4l2rds0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l2rds0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-dev:amd64.
# Preparing to unpack .../105-libv4l-dev_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-dev:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libxine2-bin.
# Preparing to unpack .../106-libxine2-bin_1.2.9-1build5_amd64.deb ...
# Unpacking libxine2-bin (1.2.9-1build5) ...
# Selecting previously unselected package libxine2-dev.
# Preparing to unpack .../107-libxine2-dev_1.2.9-1build5_amd64.deb ...
# Unpacking libxine2-dev (1.2.9-1build5) ...
# Selecting previously unselected package libxvidcore-dev:amd64.
# Preparing to unpack .../108-libxvidcore-dev_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore-dev:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../109-python-pkg-resources_44.0.0-2ubuntu0.1_all.deb ...
# Unpacking python-pkg-resources (44.0.0-2ubuntu0.1) ...
# Selecting previously unselected package python-numpy.
# Preparing to unpack .../110-python-numpy_1%3a1.16.5-2ubuntu7_amd64.deb ...
# Unpacking python-numpy (1:1.16.5-2ubuntu7) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../111-python3-numpy_1%3a1.17.4-5ubuntu3.1_amd64.deb ...
# Unpacking python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Selecting previously unselected package v4l-utils.
# Preparing to unpack .../112-v4l-utils_1.18.0-2build1_amd64.deb ...
# Unpacking v4l-utils (1.18.0-2build1) ...
# Selecting previously unselected package x264.
# Preparing to unpack .../113-x264_2%3a0.155.2917+git0a84d98-2_amd64.deb ...
# Unpacking x264 (2:0.155.2917+git0a84d98-2) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libx11-xcb-dev:amd64 (2:1.6.9-2ubuntu1.2) ...
# Setting up gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Setting up libxine2-bin (1.2.9-1build5) ...
# Setting up libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Setting up libxvidcore-dev:amd64 (2:1.3.7-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Setting up libarchive-zip-perl (1.67-2) ...
# Setting up x11proto-randr-dev (2019.2-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libfribidi-dev:amd64 (1.0.8-2ubuntu0.1) ...
# Setting up libxkbcommon-dev:amd64 (0.10.0-1) ...
# Setting up libdebhelper-perl (12.10ubuntu1) ...
# Setting up pango1.0-tools (1.44.7-2ubuntu4) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up libmp3lame-dev:amd64 (3.100-3) ...
# Setting up libtiff5-dev (4.1.0+git191117-2ubuntu0.20.04.8) ...
# Setting up gettext-base (0.19.8.1-10build1) ...
# Setting up liborc-0.4-dev-bin (1:0.4.31-1) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up libharfbuzz-gobject0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up gir1.2-atspi-2.0:amd64 (2.36.0-2) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up libfaac0:amd64 (1.30-1) ...
# Setting up libffms2-4:amd64 (2.23-4build1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-2) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-2) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libwayland-bin (1.18.0-1ubuntu0.1) ...
# Setting up libgraphite2-dev:amd64 (1.3.13-11build1) ...
# Setting up gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libtheora-dev:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# Setting up libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Setting up libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libopencore-amrwb-dev:amd64 (0.1.5-1) ...
# Setting up x11proto-input-dev (2019.2-1ubuntu1) ...
# Setting up autopoint (0.19.8.1-10build1) ...
# Setting up libcroco3:amd64 (0.6.13-1) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-2) ...
# Setting up libxcb-render0-dev:amd64 (1.14-2) ...
# Setting up python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Setting up dwz (0.13-5) ...
# Setting up wayland-protocols (1.20-1) ...
# Setting up libdatrie-dev:amd64 (0.2.12-3) ...
# Setting up libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up libv4lconvert0:amd64 (1.18.0-2build1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libv4l2rds0:amd64 (1.18.0-2build1) ...
# Setting up libsub-override-perl (0.09-2) ...
# Setting up x11proto-record-dev (2019.2-1ubuntu1) ...
# Setting up libxine2-dev (1.2.9-1build5) ...
# Setting up libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up liborc-0.4-dev:amd64 (1:0.4.31-1) ...
# Setting up libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-5) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.0-1build2) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up libxdamage-dev:amd64 (1:1.1.5-2) ...
# Setting up libfile-stripnondeterminism-perl (1.7.0-1) ...
# Setting up gstreamer1.0-gl:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Setting up gettext (0.19.8.1-10build1) ...
# Setting up libfaac-dev:amd64 (1.30-1) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Setting up python-pkg-resources (44.0.0-2ubuntu0.1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2) ...
# Setting up gir1.2-gst-plugins-base-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.24.20-0ubuntu1.1) ...
# Setting up libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up x264 (2:0.155.2917+git0a84d98-2) ...
# Setting up libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up intltool-debian (0.35.0+20060710.5) ...
# Setting up libv4l-0:amd64 (1.18.0-2build1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Setting up libopencore-amrnb-dev:amd64 (0.1.5-1) ...
# Setting up libthai-dev:amd64 (0.1.28-3) ...
# Setting up dh-strip-nondeterminism (1.7.0-1) ...
# Setting up libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up python-numpy (1:1.16.5-2ubuntu7) ...
# Setting up po-debconf (1.0.21) ...
# Setting up libepoxy-dev:amd64 (1.5.4-1) ...
# Setting up libv4l-dev:amd64 (1.18.0-2build1) ...
# Setting up v4l-utils (1.18.0-2build1) ...
# Setting up debhelper (12.10ubuntu1) ...
# Setting up dh-autoreconf (19) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libgdk-pixbuf2.0-dev:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Setting up libatk1.0-dev:amd64 (2.35.1-1ubuntu2) ...
# Setting up libatspi2.0-dev:amd64 (2.36.0-2) ...
# Setting up libharfbuzz-dev:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libatk-bridge2.0-dev:amd64 (2.34.2-0ubuntu2~20.04.1) ...
# Setting up libgstreamer-plugins-base1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libpango1.0-dev:amd64 (1.44.7-2ubuntu4) ...
# Setting up libgtk-3-dev:amd64 (3.24.20-0ubuntu1.1) ...

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights /content.gdrive/My\ Drive/darknet/test.jpg
# Out:
# /bin/bash: ./darknet: Is a directory

# %%
import cv2
import matplotlib.pyplot as plt
import os.path
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([])
ax.axis('off')
file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(show_img)
plt.show()
